# %%
import pandas as pd
from dotenv import load_dotenv
import os
from googleapiclient.discovery import build

load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("YOUTUBE_API_KEY")

if not API_KEY:
    raise ValueError("YOUTUBE_API_KEY tidak ditemukan di .env")

youtube = build("youtube", "v3", developerKey=API_KEY)

video_id = "Q_RINy6niCg"  

comments = []

request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,
    maxResults=100
)

while request:
    response = request.execute()
    
    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]
        
        comments.append({
            "text": comment["textDisplay"],
            "likes": comment["likeCount"],
            "publishedAt": comment["publishedAt"]
        })
    
    request = youtube.commentThreads().list_next(request, response)

# %%
df = pd.DataFrame(comments)

df.head()
# Out:
#                                                 text  likes  \
# 0             Umurnya, tdk jauh dr menanam jagung, 😂      0
# 1  Bukan L300 ataupun traga tap Mahindra, buktiny...      0
# 2  Apa tdk bisa produk sendiri, dari pada inpor d...      0
# 3                                        Mobil jadul      0
# 4                          Gila sih ini gilaaaa😮😮😮😮😮      0
#
#             publishedAt
# 0  2026-04-22T07:29:28Z
# 1  2026-04-13T22:30:21Z
# 2  2026-04-12T08:48:20Z
# 3  2026-04-09T16:21:18Z
# 4  2026-04-07T01:01:28Z

# %%
print(f"Jumlah data yang berhasil di scrape: {len(comments)}")
# Out:
# Jumlah data yang berhasil di scrape: 2450

# %%
df.isnull().sum()
# Out:
# text           0
# likes          0
# publishedAt    0
# dtype: int64

# %%
df.to_csv("../results/youtube/youtube_comments_3.csv", index=False, encoding="utf-8-sig")
df.to_excel("../results/youtube/youtube_comments_3.xlsx", index=False)
